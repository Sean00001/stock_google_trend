# %%
import pandas as pd
df = pd.read_csv('stock股票代號.csv')
final=pd.DataFrame()
time1 = '2020-10-26 2021-6-26'
time2 = '2021-6-27 2022-1-22'
df.head(150)
# Out:
#      股票代號
# 0    2330
# 1    2454
# 2    3008
# 3    2603
# 4    2609
# ..    ...
# 145  2885
# 146  3665
# 147  8436
# 148  3324
# 149  2610
#
# [150 rows x 1 columns]

# %%
#創建csv
colnames = ['日期','所有類別熱度','股票名稱']
header = pd.DataFrame([colnames])
header
header.to_csv('股票代號所有類別.csv',mode ='a', encoding = "Big5",header = False,index=False)

# %%
from pytrends.request import TrendReq
from pprint import pprint
import time
aa = pd.DataFrame()

cat=0
for i in range(len(df)):
    final = pd.DataFrame()
    out = pd.DataFrame()   
    pytrend = TrendReq(hl='en-US', tz=360)
    keywords =df[i:i+1]['股票代號']
    zx = int(keywords)
    keywords = [str(zx)]
    pytrend.build_payload(
         kw_list = keywords,
         cat=cat,#cat=7 為財經 cat=0 為所有類別
         timeframe= time1,
         geo='TW',
         gprop='')

    out = pytrend.interest_over_time()

    if len(out)== 0:
        print(df[i:i+1]['股票代號'])
        continue;
    else:
        if all(out.isPartial == False):
            del out['isPartial']
#         out.rename(columns={df[i:i+1]['股票名稱'].tolist()[0]: '熱度'}, inplace=True)
        out['股票代號'] = df[i:i+1]['股票代號'].tolist()[0]
        out.to_csv('股票代號所有類別.csv',mode ='a', encoding = "Big5",header = False)
        time.sleep(2)
        final = pd.DataFrame()
        out = pd.DataFrame()
        pytrend.build_payload(
         kw_list = keywords,
         cat=cat,#cat=7 為財經 cat=0 為所有類別
         timeframe= time2,
         geo='TW',
         gprop='')
        out = pytrend.interest_over_time()
        if all(out.isPartial == False):
            del out['isPartial']
#         print(out)
#         out.rename(columns={df[i:i+1]['股票名稱'].tolist()[0]: '熱度'}, inplace=True)
        out['股票代號'] = df[i:i+1]['股票代號'].tolist()[0]
        out.to_csv('股票代號所有類別.csv',mode ='a', encoding = "Big5",header = False)
        time.sleep(1)

# %%
#創建csv
colnames = ['日期','財經類別熱度','股票名稱']
header = pd.DataFrame([colnames])
header
header.to_csv('股票代號財經類別.csv',mode ='a', encoding = "Big5",header = False,index=False)

# %%
from pytrends.request import TrendReq
from pprint import pprint
import time
aa = pd.DataFrame()

cat=7
for i in range(len(df)):
    final = pd.DataFrame()
    out = pd.DataFrame()   
    pytrend = TrendReq(hl='en-US', tz=360)
    keywords =df[i:i+1]['股票代號']
    zx = int(keywords)
    keywords = [str(zx)]
    pytrend.build_payload(
         kw_list = keywords,
         cat=cat,#cat=7 為財經 cat=0 為所有類別
         timeframe= time1,
         geo='TW',
         gprop='')

    out = pytrend.interest_over_time()
    
    if len(out)== 0:
#         print(df[i:i+1]['股票代號'])
        continue;
    else:
        if 'isPartial' in out.columns:
#             if all(out.isPartial == False):
            del out['isPartial']
        else:
            print(keywords)
        
#         out.rename(columns={df[i:i+1]['股票名稱'].tolist()[0]: '熱度'}, inplace=True)
        out['股票代號'] = df[i:i+1]['股票代號'].tolist()[0]
        out.to_csv('股票代號財經類別.csv',mode ='a', encoding = "Big5",header = False)
        time.sleep(2)
        final = pd.DataFrame()
        out = pd.DataFrame()
        pytrend.build_payload(
         kw_list = keywords,
         cat=cat,#cat=7 為財經 cat=0 為所有類別
         timeframe= time2,
         geo='TW',
         gprop='')
        out = pytrend.interest_over_time()
        if 'isPartial' in out.columns:
#             if all(out.isPartial == False):
            del out['isPartial']
        else:
            print(keywords)
#         print(out)
#         out.rename(columns={df[i:i+1]['股票名稱'].tolist()[0]: '熱度'}, inplace=True)
        out['股票代號'] = df[i:i+1]['股票代號'].tolist()[0]
        out.to_csv('股票代號財經類別.csv',mode ='a', encoding = "Big5",header = False)
        time.sleep(1)
# Out:
# ['6732']
# ['1256']
# ['4966']
# ['3552']
# ['6510']
# ['6472']
# ['6491']
# ['4736']
# ['3218']
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-17-697a4ea42272> in <module>
#      52 #         out.rename(columns={df[i:i+1]['股票名稱'].tolist()[0]: '熱度'}, inplace=True)
#      53         out['股票代號'] = df[i:i+1]['股票代號'].tolist()[0]
# ---> 54         out.to_csv('股票代號財經類別.csv',mode ='a', encoding = "Big5",header = False)
#      55         time.sleep(1)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: '股票代號財經類別.csv'

# %%
pytrend = TrendReq(hl='en-US', tz=360)
    keywords =df[i:i+1]['股票代號']
    zx = int(keywords)
    keywords = [str(zx)]
    pytrend.build_payload(
         kw_list = keywords,
         cat=cat,#cat=7 為財經 cat=0 為所有類別
         timeframe= time1,
         geo='TW',
         gprop='')

    out = pytrend.interest_over_time()

# %%
df
# Out:
#      股票代號
# 0    2330
# 1    2454
# 2    3008
# 3    2603
# 4    2609
# ..    ...
# 195  2542
# 196  6683
# 197  2023
# 198  6202
# 199  1536
#
# [200 rows x 1 columns]

# %%
if '股票代號' in df.columns:
    print("Aaa")
# Out:
# Aaa

# %%
if '股票' in df.columns:
    print("Aaa")
else:
    print("不存在")
# Out:
# 不存在

# %%
# #股票代號財經類別
# from pytrends.request import TrendReq
# from pprint import pprint
# import time
# aa = pd.DataFrame()
# cat=7
# for i in range(len(df)):
#     final = pd.DataFrame()
#     out = pd.DataFrame()
#     print(final)
#     print(out)    
#     pytrend = TrendReq(hl='en-US', tz=360)
#     keywords =df[i:i+1]['股票代號']
#     zx = int(keywords)
#     keywords = [str(zx)]
#     pytrend.build_payload(
#          kw_list = keywords,
#          cat=cat,#cat=7 為財經 cat=0 為所有類別
#          timeframe= time1,
#          geo='TW',
#          gprop='')

#     out = pytrend.interest_over_time()
#     print(out)
#     print(str(df[i:i+1]['股票代號'].tolist()[0]))
#     if len(out)== 0:
#         print(df[i:i+1]['股票代號'].tolist()[0])
#         continue;
#     else:
#         out.rename(columns={str(zx): '熱度'}, inplace=True)
#         out['股票代號'] = df[i:i+1]['股票代號'].tolist()[0]
#         out.to_csv('股票代號財經類別.csv',mode ='a', encoding = "Big5")
#         time.sleep(2)
        
#         final = pd.DataFrame()
#         out = pd.DataFrame()
        
        
#         pytrend.build_payload(
#          kw_list = keywords,
#          cat=cat,#cat=7 為財經 cat=0 為所有類別
#          timeframe= time2,
#          geo='TW',
#          gprop='')
#         out = pytrend.interest_over_time()
#         print(out)
#         out.rename(columns={str(zx): '熱度'}, inplace=True)
#         out['股票代號'] = df[i:i+1]['股票代號'].tolist()[0]
#         out.to_csv('股票代號財經類別.csv',mode ='a', encoding = "Big5",header = False)
#         time.sleep(1)
